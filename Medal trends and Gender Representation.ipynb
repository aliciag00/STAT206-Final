# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
countries = pd.read_csv("CountriesSD.csv")
summer = pd.read_csv("SummerSD.csv")
winter = pd.read_csv("WinterSD.csv")

# %% [markdown]
# ## Kim's Edits below (Analysis on the Role of Gender and its Correlation to Medals Won)

# %%
#clean any missing values from each dataset
clean_countries = countries.dropna()
clean_countries
# Out:
#      Unnamed: 0              Country Code  Population  GDP per Capita
# 0             0          Afghanistan  AFG  32526562.0      594.323081
# 1             1              Albania  ALB   2889167.0     3945.217582
# 2             2              Algeria  ALG  39666519.0     4206.031232
# 5             5               Angola  ANG  25021974.0     4101.472152
# 6             6  Antigua and Barbuda  ANT     91818.0    13714.731962
# ..          ...                  ...  ...         ...             ...
# 194         194              Vanuatu  VAN    264652.0     2805.314644
# 196         196              Vietnam  VIE  91703800.0     2111.138024
# 198         198                Yemen  YEM  26832215.0     1406.291651
# 199         199               Zambia  ZAM  16211767.0     1304.879014
# 200         200             Zimbabwe  ZIM  15602751.0      924.143819
#
# [176 rows x 5 columns]

# %%
clean_summer = summer.dropna()
clean_summer
# Out:
#        Unnamed: 0  Year    City      Sport           Discipline  \
# 0               0  1896  Athens   Aquatics             Swimming
# 1               1  1896  Athens   Aquatics             Swimming
# 2               2  1896  Athens   Aquatics             Swimming
# 3               3  1896  Athens   Aquatics             Swimming
# 4               4  1896  Athens   Aquatics             Swimming
# ...           ...   ...     ...        ...                  ...
# 31160       31160  2012  London  Wrestling  Wrestling Freestyle
# 31161       31161  2012  London  Wrestling  Wrestling Freestyle
# 31162       31162  2012  London  Wrestling  Wrestling Freestyle
# 31163       31163  2012  London  Wrestling  Wrestling Freestyle
# 31164       31164  2012  London  Wrestling  Wrestling Freestyle
#
#                         Athlete Code Gender                       Event  \
# 0                  Alfred Hajos  HUN    Men              100M Freestyle
# 1               Otto Herschmann  AUT    Men              100M Freestyle
# 2              Dimitrios Drivas  GRE    Men  100M Freestyle For Sailors
# 3             Ioannis Malokinis  GRE    Men  100M Freestyle For Sailors
# 4             Spiridon Chasapis  GRE    Men  100M Freestyle For Sailors
# ...                         ...  ...    ...                         ...
# 31160         Damian Janikowski  POL    Men                    Wg 84 KG
# 31161  Ghasem Gholamreza Rezaei  IRI    Men                    Wg 96 KG
# 31162             Rustam Totrov  RUS    Men                    Wg 96 KG
# 31163          Artur Aleksanyan  ARM    Men                    Wg 96 KG
# 31164             Jimmy Lidberg  SWE    Men                    Wg 96 KG
#
#         Medal  Country
# 0        Gold  Hungary
# 1      Silver  Austria
# 2      Bronze   Greece
# 3        Gold   Greece
# 4      Silver   Greece
# ...       ...      ...
# 31160  Bronze   Poland
# 31161    Gold     Iran
# 31162  Silver   Russia
# 31163  Bronze  Armenia
# 31164  Bronze   Sweden
#
# [25742 rows x 11 columns]

# %%
clean_winter = winter.dropna()
clean_winter
# Out:
#       Unnamed: 0  Year      City     Sport Discipline               Athlete  \
# 0              0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.
# 1              1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.
# 2              2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice
# 3              3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André
# 4              4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf
# ...          ...   ...       ...       ...        ...                   ...
# 5765        5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny
# 5766        5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie
# 5767        5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique
# 5768        5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva
# 5769        5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe
#
#      Country Gender            Event   Medal
# 0        FRA    Men  Military Patrol  Bronze
# 1        FRA    Men  Military Patrol  Bronze
# 2        FRA    Men  Military Patrol  Bronze
# 3        FRA    Men  Military Patrol  Bronze
# 4        SUI    Men  Military Patrol    Gold
# ...      ...    ...              ...     ...
# 5765     GBR  Women       Slopestyle  Bronze
# 5766     USA  Women       Slopestyle    Gold
# 5767     CAN  Women  Snowboard Cross  Silver
# 5768     CZE  Women  Snowboard Cross    Gold
# 5769     FRA  Women  Snowboard Cross  Bronze
#
# [5770 rows x 10 columns]

# %%
Summer_Games_by_Year = clean_summer.sort_values(by='Year', ascending=False)

# %%
winter.sort_values(by='Year', ascending=False)
# Out:
#       Unnamed: 0  Year      City       Sport      Discipline  \
# 5769        5769  2014     Sochi      Skiing       Snowboard
# 5358        5358  2014     Sochi  Ice Hockey      Ice Hockey
# 5365        5365  2014     Sochi  Ice Hockey      Ice Hockey
# 5364        5364  2014     Sochi  Ice Hockey      Ice Hockey
# 5363        5363  2014     Sochi  Ice Hockey      Ice Hockey
# ...          ...   ...       ...         ...             ...
# 84            84  1924  Chamonix     Skating  Figure skating
# 85            85  1924  Chamonix     Skating  Figure skating
# 86            86  1924  Chamonix     Skating  Figure skating
# 87            87  1924  Chamonix     Skating  Figure skating
# 0              0  1924  Chamonix    Biathlon        Biathlon
#
#                   Athlete Country Gender            Event   Medal
# 5769     TRESPEUCH, Chloe     FRA  Women  Snowboard Cross  Bronze
# 5358         IRWIN, Haley     CAN  Women       Ice Hockey    Gold
# 5365  OUELLETTE, Caroline     CAN  Women       Ice Hockey    Gold
# 5364   MIKKELSON, Meaghan     CAN  Women       Ice Hockey    Gold
# 5363   LAROCQUE, Jocelyne     CAN  Women       Ice Hockey    Gold
# ...                   ...     ...    ...              ...     ...
# 84         BRUNET, Andrée     FRA  Women            Pairs  Bronze
# 85         BRUNET, Pierre     FRA    Men            Pairs  Bronze
# 86         BERGER, Alfred     AUT    Men            Pairs    Gold
# 87      ENGELMANN, Helene     AUT  Women            Pairs    Gold
# 0             BERTHET, G.     FRA    Men  Military Patrol  Bronze
#
# [5770 rows x 10 columns]

# %%
Winter_Games_by_Year = clean_winter.sort_values(by='Year', ascending=False)
Winter_Games_by_Year
# Out:
#       Unnamed: 0  Year      City       Sport      Discipline  \
# 5769        5769  2014     Sochi      Skiing       Snowboard
# 5358        5358  2014     Sochi  Ice Hockey      Ice Hockey
# 5365        5365  2014     Sochi  Ice Hockey      Ice Hockey
# 5364        5364  2014     Sochi  Ice Hockey      Ice Hockey
# 5363        5363  2014     Sochi  Ice Hockey      Ice Hockey
# ...          ...   ...       ...         ...             ...
# 84            84  1924  Chamonix     Skating  Figure skating
# 85            85  1924  Chamonix     Skating  Figure skating
# 86            86  1924  Chamonix     Skating  Figure skating
# 87            87  1924  Chamonix     Skating  Figure skating
# 0              0  1924  Chamonix    Biathlon        Biathlon
#
#                   Athlete Country Gender            Event   Medal
# 5769     TRESPEUCH, Chloe     FRA  Women  Snowboard Cross  Bronze
# 5358         IRWIN, Haley     CAN  Women       Ice Hockey    Gold
# 5365  OUELLETTE, Caroline     CAN  Women       Ice Hockey    Gold
# 5364   MIKKELSON, Meaghan     CAN  Women       Ice Hockey    Gold
# 5363   LAROCQUE, Jocelyne     CAN  Women       Ice Hockey    Gold
# ...                   ...     ...    ...              ...     ...
# 84         BRUNET, Andrée     FRA  Women            Pairs  Bronze
# 85         BRUNET, Pierre     FRA    Men            Pairs  Bronze
# 86         BERGER, Alfred     AUT    Men            Pairs    Gold
# 87      ENGELMANN, Helene     AUT  Women            Pairs    Gold
# 0             BERTHET, G.     FRA    Men  Military Patrol  Bronze
#
# [5770 rows x 10 columns]

# %% [markdown]
# ### Summer Games analysis below

# %%
# for each Summer and Winter games now lets split the data up between men and women and then sort in descending order to get the most recent games for each. 
summer_male_olympians = summer[summer['Gender'] == 'Men']
summer_female_olympians = summer[summer['Gender'] == 'Women']

summer_male_olympians.sort_values(by='Year', ascending=False).head(1000)
# Out:
#        Unnamed: 0  Year    City      Sport           Discipline  \
# 31164       31164  2012  London  Wrestling  Wrestling Freestyle
# 29761       29761  2012  London  Athletics            Athletics
# 29921       29921  2012  London      Canoe         Canoe Slalom
# 29920       29920  2012  London      Canoe         Canoe Slalom
# 29919       29919  2012  London     Boxing               Boxing
# ...           ...   ...     ...        ...                  ...
# 30500       30500  2012  London     Hockey               Hockey
# 30585       30585  2012  London       Judo                 Judo
# 30527       30527  2012  London     Hockey               Hockey
# 30608       30608  2012  London       Judo                 Judo
# 30514       30514  2012  London     Hockey               Hockey
#
#                  Athlete Code Gender         Event   Medal      Country
# 31164      Jimmy Lidberg  SWE    Men      Wg 96 KG  Bronze       Sweden
# 29761        David Storl  GER    Men      Shot Put  Silver      Germany
# 29921   Sideris Tasiadis  GER    Men  C-1 (Single)  Silver      Germany
# 29920     Tony Estanguet  FRA    Men  C-1 (Single)    Gold       France
# 29919       Tervel Pulev  BUL    Men     81 - 91KG  Bronze     Bulgaria
# ...                  ...  ...    ...           ...     ...          ...
# 30500  Marcel Balkestein  NED    Men        Hockey  Silver  Netherlands
# 30585     Felipe Kitadai  BRA    Men       - 60 KG  Bronze       Brazil
# 30527    Edward Ockenden  AUS    Men        Hockey  Bronze    Australia
# 30608     Miklos Ungvari  HUN    Men     60 - 66KG  Silver      Hungary
# 30514  Roderick Weusthof  NED    Men        Hockey  Silver  Netherlands
#
# [1000 rows x 11 columns]

# %%
summer_female_olympians.sort_values(by='Year', ascending=False).head(15)
# Out:
#        Unnamed: 0  Year    City       Sport           Discipline  \
# 31124       31124  2012  London   Wrestling  Wrestling Freestyle
# 29841       29841  2012  London  Basketball           Basketball
# 29839       29839  2012  London  Basketball           Basketball
# 29838       29838  2012  London  Basketball           Basketball
# 29837       29837  2012  London  Basketball           Basketball
# 29836       29836  2012  London  Basketball           Basketball
# 29835       29835  2012  London  Basketball           Basketball
# 29834       29834  2012  London  Basketball           Basketball
# 29833       29833  2012  London  Basketball           Basketball
# 29832       29832  2012  London  Basketball           Basketball
# 29795       29795  2012  London   Badminton            Badminton
# 29794       29794  2012  London   Badminton            Badminton
# 29793       29793  2012  London   Badminton            Badminton
# 29789       29789  2012  London   Badminton            Badminton
# 29786       29786  2012  London   Badminton            Badminton
#
#                    Athlete Code Gender       Event   Medal        Country
# 31124          Maider Unda  ESP  Women    Wf 72 KG  Bronze          Spain
# 29841       Candace Parker  USA  Women  Basketball    Gold  United States
# 29839     Angel Mccoughtry  USA  Women  Basketball    Gold  United States
# 29838          Asjha Jones  USA  Women  Basketball    Gold  United States
# 29837        Sylvia Fowles  USA  Women  Basketball    Gold  United States
# 29836         Tina Charles  USA  Women  Basketball    Gold  United States
# 29835     Tamika Catchings  USA  Women  Basketball    Gold  United States
# 29834            Swin Cash  USA  Women  Basketball    Gold  United States
# 29833             Sue Bird  USA  Women  Basketball    Gold  United States
# 29832     Seimone Augustus  USA  Women  Basketball    Gold  United States
# 29795         Saina Nehwal  IND  Women     Singles  Bronze          India
# 29794           Yihan Wang  CHN  Women     Singles  Silver          China
# 29793            Xuerui Li  CHN  Women     Singles    Gold          China
# 29789  Christinna Pedersen  DEN  Women     Doubles  Bronze        Denmark
# 29786               Jin Ma  CHN  Women     Doubles  Silver          China

# %%
summer_female_olympians.sort_values(by='Year', ascending=False).head(15)

#This will help us see how many female atheletes there are in each discipline for the summer olympics
summer_female_olympians.groupby('Discipline').size()

#nthis will help us see  which ones have medals won 
summer_female_olympians.groupby('Medal').size()

#this will now let us combine the two above so the number of female metals per each disicipline for the summer olympics
summer_female_olympians.groupby(['Discipline', 'Medal']).size()
# Out:
# Discipline           Medal
# Archery              Bronze     35
#                      Gold       39
#                      Silver     37
# Artistic G.          Bronze    216
#                      Gold      216
#                               ...
# Wrestling Free.      Gold        8
#                      Silver      8
# Wrestling Freestyle  Bronze      8
#                      Gold        4
#                      Silver      4
# Length: 156, dtype: int64

# %%
summer_female_olympians.groupby(['Discipline', 'Medal']).size().head(30)
# Out:
# Discipline        Medal
# Archery           Bronze     35
#                   Gold       39
#                   Silver     37
# Artistic G.       Bronze    216
#                   Gold      216
#                   Silver    211
# Athletics         Bronze    381
#                   Gold      389
#                   Silver    393
# BMX               Bronze      1
#                   Gold        1
#                   Silver      1
# Badminton         Bronze     26
#                   Gold       23
#                   Silver     23
# Basketball        Bronze    119
#                   Gold      120
#                   Silver    120
# Beach Volleyball  Bronze      2
#                   Gold        2
#                   Silver      2
# Beach volley.     Bronze      8
#                   Gold        8
#                   Silver      8
# Boxing            Bronze      6
#                   Gold        3
#                   Silver      3
# Canoe / Kayak F   Bronze     70
#                   Gold       70
#                   Silver     70
# dtype: int64

# %%
summer_male_olympians.sort_values(by='Year', ascending=False).head(15)

#This will help us see how many male atheletes there are in each discipline for the summer olympics
summer_male_olympians.groupby('Discipline').size()

#nthis will help us see  which ones have medals won 
summer_male_olympians.groupby('Medal').size()

#this will now let us combine the two above so the number of male metals per each disicipline for the summer olympics
summer_male_olympians.groupby(['Discipline', 'Medal']).size()
# Out:
# Discipline           Medal
# Archery              Bronze     55
#                      Gold       87
#                      Silver     76
# Artistic G.          Bronze    447
#                      Gold      536
#                               ...
# Wrestling Freestyle  Gold       14
#                      Silver     14
# Wrestling Gre-R      Bronze    187
#                      Gold      180
#                      Silver    182
# Length: 181, dtype: int64

# %%
summer_male_olympians.groupby(['Discipline', 'Medal']).size().head(30)
# Out:
# Discipline        Medal
# Archery           Bronze     55
#                   Gold       87
#                   Silver     76
# Artistic G.       Bronze    447
#                   Gold      536
#                   Silver    477
# Athletics         Bronze    818
#                   Gold      826
#                   Silver    831
# BMX               Bronze      1
#                   Gold        1
#                   Silver      1
# Badminton         Bronze     26
#                   Gold       23
#                   Silver     23
# Baseball          Bronze    112
#                   Gold      111
#                   Silver    112
# Basketball        Bronze    215
#                   Gold      222
#                   Silver    216
# Basque Pelota     Gold        2
#                   Silver      2
# Beach Volleyball  Bronze      2
#                   Gold        2
#                   Silver      2
# Beach volley.     Bronze      8
#                   Gold        8
#                   Silver      8
# Boxing            Bronze    410
# dtype: int64

# %% [markdown]
# ### Winter Games analysis below

# %%
#now to split it up into the winter olympics and do the same thing as above

winter_male_olympians = winter[winter['Gender'] == 'Men']

winter_female_olympians = winter[winter['Gender'] == 'Women']

winter_male_olympians.sort_values(by='Year', ascending=False).head(15)
# Out:
#       Unnamed: 0  Year   City       Sport  Discipline             Athlete  \
# 5754        5754  2014  Sochi      Skiing   Snowboard       DEIBOLD, Alex
# 5327        5327  2014  Sochi  Ice Hockey  Ice Hockey       VATANEN, Sami
# 5319        5319  2014  Sochi  Ice Hockey  Ice Hockey    PIHLSTROM, Antti
# 5320        5320  2014  Sochi  Ice Hockey  Ice Hockey        RASK, Tuukka
# 5321        5321  2014  Sochi  Ice Hockey  Ice Hockey        RUUTU, Tuomo
# 5322        5322  2014  Sochi  Ice Hockey  Ice Hockey    SALMINEN, Sakari
# 5323        5323  2014  Sochi  Ice Hockey  Ice Hockey          SALO, Sami
# 5324        5324  2014  Sochi  Ice Hockey  Ice Hockey      SELANNE, Teemu
# 5325        5325  2014  Sochi  Ice Hockey  Ice Hockey      TIMONEN, Kimmo
# 5326        5326  2014  Sochi  Ice Hockey  Ice Hockey      VAANANEN, Ossi
# 5328        5328  2014  Sochi  Ice Hockey  Ice Hockey  ALFREDSSON, Daniel
# 5338        5338  2014  Sochi  Ice Hockey  Ice Hockey       HAGELIN, Carl
# 5329        5329  2014  Sochi  Ice Hockey  Ice Hockey  BACKSTROM, Nicklas
# 5330        5330  2014  Sochi  Ice Hockey  Ice Hockey    BERGLUND, Patrik
# 5331        5331  2014  Sochi  Ice Hockey  Ice Hockey    EDLER, Alexander
#
#      Country Gender            Event   Medal
# 5754     USA    Men  Snowboard Cross  Bronze
# 5327     FIN    Men       Ice Hockey  Bronze
# 5319     FIN    Men       Ice Hockey  Bronze
# 5320     FIN    Men       Ice Hockey  Bronze
# 5321     FIN    Men       Ice Hockey  Bronze
# 5322     FIN    Men       Ice Hockey  Bronze
# 5323     FIN    Men       Ice Hockey  Bronze
# 5324     FIN    Men       Ice Hockey  Bronze
# 5325     FIN    Men       Ice Hockey  Bronze
# 5326     FIN    Men       Ice Hockey  Bronze
# 5328     SWE    Men       Ice Hockey  Silver
# 5338     SWE    Men       Ice Hockey  Silver
# 5329     SWE    Men       Ice Hockey  Silver
# 5330     SWE    Men       Ice Hockey  Silver
# 5331     SWE    Men       Ice Hockey  Silver

# %%
winter_female_olympians.sort_values(by='Year', ascending=False).head(15)

#This will help us see how many female atheletes there are in each discipline for the winter olympics
winter_female_olympians.groupby('Discipline').size()

#nthis will help us see  which ones have medals won 
winter_female_olympians.groupby('Medal').size()

#this will now let us combine the two above so the number of female metals per each disicipline for the winter olympics
winter_female_olympians.groupby(['Discipline', 'Medal']).size()
# Out:
# Discipline                 Medal
# Alpine Skiing              Bronze     69
#                            Gold       72
#                            Silver     72
# Biathlon                   Bronze     50
#                            Gold       50
#                            Silver     50
# Bobsleigh                  Bronze      8
#                            Gold        8
#                            Silver      8
# Cross Country Skiing       Bronze    113
#                            Gold      113
#                            Silver    113
# Curling                    Bronze     25
#                            Gold       25
#                            Silver     25
# Figure skating             Bronze     59
#                            Gold       61
#                            Silver     59
# Freestyle Skiing           Bronze     17
#                            Gold       17
#                            Silver     17
# Ice Hockey                 Bronze    102
#                            Gold      101
#                            Silver    102
# Luge                       Bronze     15
#                            Gold       15
#                            Silver     15
# Short Track Speed Skating  Bronze     48
#                            Gold       48
#                            Silver     47
# Skeleton                   Bronze      4
#                            Gold        4
#                            Silver      4
# Ski Jumping                Bronze      1
#                            Gold        1
#                            Silver      1
# Snowboard                  Bronze     15
#                            Gold       15
#                            Silver     15
# Speed skating              Bronze     78
#                            Gold       81
#                            Silver     83
# dtype: int64

# %%
Winter_Female_Olympian_Medals_By_Discipline = winter_female_olympians.groupby(['Discipline', 'Medal']).size().head(21)
Winter_Female_Olympian_Medals_By_Discipline
# Out:
# Discipline            Medal
# Alpine Skiing         Bronze     69
#                       Gold       72
#                       Silver     72
# Biathlon              Bronze     50
#                       Gold       50
#                       Silver     50
# Bobsleigh             Bronze      8
#                       Gold        8
#                       Silver      8
# Cross Country Skiing  Bronze    113
#                       Gold      113
#                       Silver    113
# Curling               Bronze     25
#                       Gold       25
#                       Silver     25
# Figure skating        Bronze     59
#                       Gold       61
#                       Silver     59
# Freestyle Skiing      Bronze     17
#                       Gold       17
#                       Silver     17
# dtype: int64

# %%
winter_male_olympians.sort_values(by='Year', ascending=False).head(15)

#This will help us see how many male atheletes there are in each discipline for the winter olympics
winter_male_olympians.groupby('Discipline').size()

#nthis will help us see  which ones have medals won 
winter_male_olympians.groupby('Medal').size()

#this will now let us combine the two above so the number of female metals per each disicipline for the winter olympics
Winter_Male_Olympian_Medals_By_Discipline = winter_male_olympians.groupby(['Discipline', 'Medal']).size().head(15)
Winter_Male_Olympian_Medals_By_Discipline

#this will now let us combine the two above so the number of female metals per each disicipline for the winter olympics
winter_male_olympians.groupby(['Discipline', 'Medal']).size()
# Out:
# Discipline                 Medal
# Alpine Skiing              Bronze     72
#                            Gold       71
#                            Silver     72
# Biathlon                   Bronze     89
#                            Gold       90
#                            Silver     91
# Bobsleigh                  Bronze    139
#                            Gold      126
#                            Silver    133
# Cross Country Skiing       Bronze    150
#                            Gold      151
#                            Silver    149
# Curling                    Bronze     31
#                            Gold       33
#                            Silver     33
# Figure skating             Bronze     59
#                            Gold       61
#                            Silver     60
# Freestyle Skiing           Bronze     17
#                            Gold       17
#                            Silver     17
# Ice Hockey                 Bronze    410
#                            Gold      409
#                            Silver    412
# Luge                       Bronze     45
#                            Gold       47
#                            Silver     43
# Nordic Combined            Bronze     55
#                            Gold       55
#                            Silver     55
# Short Track Speed Skating  Bronze     48
#                            Gold       49
#                            Silver     50
# Skeleton                   Bronze      6
#                            Gold        6
#                            Silver      6
# Ski Jumping                Bronze     67
#                            Gold       68
#                            Silver     69
# Snowboard                  Bronze     15
#                            Gold       15
#                            Silver     15
# Speed skating              Bronze    112
#                            Gold      112
#                            Silver    114
# dtype: int64

# %%
Winter_Male_Olympian_Medals_By_Discipline = winter_male_olympians.groupby(['Discipline', 'Medal']).size().head(15)

# %%
Winter_Male_Olympian_Medals_By_Discipline.plot(kind='bar', stacked=True, figsize=(16, 12), color=['sienna', 'gold', 'silver'])
plt.title('Medal Types and Counts for Male Olympians by Discipline (Winter Games)')
plt.xlabel('Discipline')
plt.ylabel('Number of Medals')
plt.legend(title='Medal Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kimca\AppData\Local\Temp\ipykernel_9404\1720693481.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Medal Type')

# %%
Winter_Female_Olympian_Medals_By_Discipline.plot(kind='bar', stacked=True, figsize=(16, 12), color=['sienna', 'gold', 'silver'])
plt.title('Medal Types and Counts for Female Olympians by Discipline (Winter Games)')
plt.xlabel('Discipline')
plt.ylabel('Number of Medals')
plt.legend(title='Medal Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kimca\AppData\Local\Temp\ipykernel_9404\1251169544.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Medal Type')
